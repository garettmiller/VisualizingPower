# %%
import altair as alt
from altair_saver import save
import importlib
import Sipri
from vega_datasets import data
from IPython.display import display, HTML

importlib.reload(Sipri)
sipri = Sipri.Sipri("C:/Users/mille/PycharmProjects/VisualizingPower/venv/Include/SIPRI-Milex-data-1949-2020_0.xlsx")

meaningful_world = list(range(1992, 2021))


#War Chart

labels = sipri.get_labels_from_dict({1950: "Korean War starts",
                             1953: "Korean War ends",
                             1955: "Vietnam War starts",
                             1975: "Vietnam War ends",
                             1990: "Gulf War",
                             1992: "Soviet Union falls",
                             2001: "Invasion of Afghanistan starts",
                             2003: "Iraq War starts",
                             2011: "Iraq War ends",
                             2022: "Invasion of Afghanistan ends"}, list(range(1950, 2021)))
us_budget_line, us_budget_df = sipri.budget_line_chart(["USA"], 'US Military Spending with War Tags',list(range(1950, 2021, 5)), 2021, labels)
us_budget_line
# Out:
# C:\Users\mille\PycharmProjects\VisualizingPower\venv\src\Sipri.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Year"] = pd.to_numeric(df["Year"], downcast="integer")
# alt.LayerChart(...)

# %%
strong_and_enemies = ["USA", "China", "Russia", "Iran", "Pakistan", "Turkey"]
budget_line, line_df = sipri.budget_line_chart(strong_and_enemies, meaningful_world[::5])
budget_bar, bar_df = sipri.spending_bar_chart(strong_and_enemies, meaningful_world)
display(bar_df)
budget_line | budget_bar
# Out:
#              Year        Budget
# Country
# China     58174.0  3.069659e+06
# Iran      58174.0  3.474664e+05
# Pakistan  58174.0  1.827137e+05
# Russia    58174.0  1.299072e+06
# Turkey    58174.0  3.516407e+05
# USA       58174.0  1.876494e+07
# alt.HConcatChart(...)

# %%
invaded = ["USA", "Vietnam", "Afghanistan", "Cambodia", "Laos", "Korea, South", "Venezuela", "Chile", "Nicaragua", "Iraq"]
invaded_years = list(range(1992, 2014))
budget_line, line_df = sipri.budget_line_chart(invaded, 'US Military Budget vs. Countries US Intervened In', invaded_years[::5], 2014)
budget_bar, bar_df = sipri.spending_bar_chart(invaded, 'Aggregate US Military Spending vs. Countries US Intervened In', invaded_years)
budget_bar | budget_line
# Out:
# alt.HConcatChart(...)

# %%
regions = ['Africa', 'Americas', 'Asia and Oceania', 'Europe', 'Middle East (excluding Iraq)']
region_line = sipri.regional_budget_line_chart(regions, meaningful_world[::5])
region_bar, bar_df = sipri.regional_spending_bar_chart(regions, meaningful_world[::5])
display(bar_df)
region_line | region_bar
# Out:
# C:\Users\mille\PycharmProjects\VisualizingPower\venv\src\Sipri.py:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Budget"] = df["Budget"].map(lambda item : item / 1000)
#                     Year        Budget
# Region
# Africa             58174    823.692338
# Americas minus US  58174   1786.099037
# Asia and Oceania   58174   8571.588983
# Europe             58174   9158.061147
# USA                58174  18764.937203
# alt.HConcatChart(...)

# %%
carrier_cost = 12800
carrier_price = sipri.budget_under_price(carrier_cost)
budget_histogram = sipri.budget_histogram(2019)
budget_histogram | carrier_price
# Out:
# alt.HConcatChart(...)

# %%
histograms = []
scale = .1
for x in range(6):
    histograms.append(sipri.budget_histogram_by_scale(2019, scale))
    scale = scale * 10

(histograms[5] | histograms[4] | histograms[3]) & (histograms[2] | histograms[1] | histograms[0])
# Out:
# alt.VConcatChart(...)

# %%
df = sipri.constant_USD.df
df.loc[df['Country'] == 'Brazil']
# Out:
#       Year Country        Budget
# 5479  1953  Brazil   1687.227742
# 5483  1957  Brazil   2545.067114
# 5484  1958  Brazil   2547.123119
# 5485  1959  Brazil   2020.912940
# 5486  1960  Brazil   1854.855692
# ...    ...     ...           ...
# 5542  2016  Brazil  23835.797620
# 5543  2017  Brazil  25389.543399
# 5544  2018  Brazil  27074.280490
# 5545  2019  Brazil  25906.871197
# 5546  2020  Brazil  25101.252046
#
# [65 rows x 3 columns]
